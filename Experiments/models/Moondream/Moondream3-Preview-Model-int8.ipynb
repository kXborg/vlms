# %% [markdown]
# <h2 style="color: #40a3ff;">Moondream3 Preview Model</h2>
# <p><img src="https://moondream.ai/_next/image?url=%2Fimages%2Fblog%2Fmoondream-3-preview%2Ftitle-image.jpg&w=1920&q=75" alt="Moondream3" style="height:400px"> <img src="md_logo.svg" alt="Moondream3-Logo" style="height:400px"></p>

# %%
import torch
import time
from PIL import Image, ImageDraw
# %matplotlib inline
import matplotlib.pyplot as plt
plt.rcParams['image.cmap'] = 'gray'
from transformers import AutoModelForCausalLM, AutoTokenizer

# %% [markdown]
# ### Load Model

# %%
# !pip show bitsandbytes-windows
# Out:
# Name: bitsandbytes-windows
# Version: 0.37.5
# Summary: 8-bit optimizers and matrix multiplication routines.
# Home-page: https://github.com/Keith-Hon/bitsandbytes-windows
# Author: Tim Dettmers
# Author-email: dettmers@cs.washington.edu
# License: MIT
# Location: c:\users\user\.conda\envs\vlm\lib\site-packages
# Requires:
# Required-by:

# %%
from transformers import AutoModelForCausalLM, BitsAndBytesConfig

model_id = "moondream/moondream3-preview"

quant_config = BitsAndBytesConfig(
    load_in_8bit=True,         # or load_in_4bit=True
    llm_int8_enable_fp32_cpu_offload=True
)

moondream = AutoModelForCausalLM.from_pretrained(
    model_id,
    trust_remote_code=True,
    quantization_config=quant_config,
    device_map="auto",
)

moondream.compile()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[19], line 10
#       3 model_id = "moondream/moondream3-preview"
#       5 quant_config = BitsAndBytesConfig(
#       6     load_in_8bit=True,         # or load_in_4bit=True
#       7     llm_int8_enable_fp32_cpu_offload=True
#       8 )
# ---> 10 moondream = AutoModelForCausalLM.from_pretrained(
#      11     model_id,
#      12     trust_remote_code=True,
#      13     quantization_config=quant_config,
#      14     device_map="auto",
#      15 )
#      17 moondream.compile()
#
# File ~\.conda\envs\vlm\lib\site-packages\transformers\models\auto\auto_factory.py:597, in _BaseAutoModelClass.from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     595         model_class.register_for_auto_class(auto_class=cls)
#     596     model_class = add_generation_mixin_to_remote_model(model_class)
# --> 597     return model_class.from_pretrained(
#     598         pretrained_model_name_or_path, *model_args, config=config, **hub_kwargs, **kwargs
#     599     )
#     600 elif type(config) in cls._model_mapping:
#     601     model_class = _get_model_class(config, cls._model_mapping)
#
# File ~\.conda\envs\vlm\lib\site-packages\transformers\modeling_utils.py:288, in restore_default_dtype.<locals>._wrapper(*args, **kwargs)
#     286 old_dtype = torch.get_default_dtype()
#     287 try:
# --> 288     return func(*args, **kwargs)
#     289 finally:
#     290     torch.set_default_dtype(old_dtype)
#
# File ~\.conda\envs\vlm\lib\site-packages\transformers\modeling_utils.py:5008, in PreTrainedModel.from_pretrained(cls, pretrained_model_name_or_path, config, cache_dir, ignore_mismatched_sizes, force_download, local_files_only, token, revision, use_safetensors, weights_only, *model_args, **kwargs)
#    4999     if not transformers_explicit_filename.endswith(
#    5000         ".safetensors"
#    5001     ) and not transformers_explicit_filename.endswith(".safetensors.index.json"):
#    5002         raise ValueError(
#    5003             "The transformers file in the config seems to be incorrect: it is neither a safetensors file "
#    5004             "(*.safetensors) nor a safetensors index file (*.safetensors.index.json): "
#    5005             f"{transformers_explicit_filename}"
#    5006         )
# -> 5008 hf_quantizer, config, dtype, device_map = get_hf_quantizer(
#    5009     config, quantization_config, dtype, from_tf, from_flax, device_map, weights_only, user_agent
#    5010 )
#    5012 if gguf_file is not None and hf_quantizer is not None:
#    5013     raise ValueError(
#    5014         "You cannot combine Quantization and loading a model from a GGUF file, try again by making sure you did not passed a `quantization_config` or that you did not load a quantized model from the Hub."
#    5015     )
#
# File ~\.conda\envs\vlm\lib\site-packages\transformers\quantizers\auto.py:319, in get_hf_quantizer(config, quantization_config, dtype, from_tf, from_flax, device_map, weights_only, user_agent)
#     316     hf_quantizer = None
#     318 if hf_quantizer is not None:
# --> 319     hf_quantizer.validate_environment(
#     320         dtype=dtype,
#     321         from_tf=from_tf,
#     322         from_flax=from_flax,
#     323         device_map=device_map,
#     324         weights_only=weights_only,
#     325     )
#     326     dtype = hf_quantizer.update_dtype(dtype)
#     327     device_map = hf_quantizer.update_device_map(device_map)
#
# File ~\.conda\envs\vlm\lib\site-packages\transformers\quantizers\quantizer_bnb_8bit.py:73, in Bnb8BitHfQuantizer.validate_environment(self, *args, **kwargs)
#      69     raise ImportError(
#      70         f"Using `bitsandbytes` 8-bit quantization requires Accelerate: `pip install 'accelerate>={ACCELERATE_MIN_VERSION}'`"
#      71     )
#      72 if not is_bitsandbytes_available(check_library_only=True):
# ---> 73     raise ImportError(
#      74         "Using `bitsandbytes` 8-bit quantization requires the latest version of bitsandbytes: `pip install -U bitsandbytes`"
#      75     )
#      76 if not is_torch_available():
#      77     raise ImportError(
#      78         "The bitsandbytes library requires PyTorch but it was not found in your environment. "
#      79         "You can install it with `pip install torch`."
#      80     )
#
# ImportError: Using `bitsandbytes` 8-bit quantization requires the latest version of bitsandbytes: `pip install -U bitsandbytes`

# %%
# !nvidia-smi
# Out:
# Mon Sep 22 14:30:20 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 560.94                 Driver Version: 560.94         CUDA Version: 12.6     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                  Driver-Model | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce RTX 3060      WDDM  |   00000000:01:00.0  On |                  N/A |
# |  0%   39C    P8             18W /  170W |     846MiB /  12288MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |    0   N/A  N/A       420    C+G   ...s\System32\ApplicationFrameHost.exe      N/A      |
# |    0   N/A  N/A      3476    C+G   ...cw5n1h2txyewy\CrossDeviceResume.exe      N/A      |
# |    0   N/A  N/A      4064    C+G   ...t.LockApp_cw5n1h2txyewy\LockApp.exe      N/A      |
# |    0   N/A  N/A      6208    C+G   C:\Windows\System32\ShellHost.exe           N/A      |
# |    0   N/A  N/A      6904    C+G   ...oogle\Chrome\Application\chrome.exe      N/A      |
# |    0   N/A  N/A      7428    C+G   ...3d8bbwe\dotnet\PAD.Console.Host.exe      N/A      |
# |    0   N/A  N/A      8044    C+G   ...oogle\Chrome\Application\chrome.exe      N/A      |
# |    0   N/A  N/A      9604    C+G   ...2txyewy\StartMenuExperienceHost.exe      N/A      |
# |    0   N/A  N/A     11728    C+G   ...nt.CBS_cw5n1h2txyewy\SearchHost.exe      N/A      |
# |    0   N/A  N/A     13240    C+G   ...5n1h2txyewy\ShellExperienceHost.exe      N/A      |
# |    0   N/A  N/A     13988    C+G   ...__8wekyb3d8bbwe\WindowsTerminal.exe      N/A      |
# |    0   N/A  N/A     14200    C+G   ...on\140.0.3485.81\msedgewebview2.exe      N/A      |
# |    0   N/A  N/A     14260    C+G   ....0_x64__8she8kybcnzg4\app\Slack.exe      N/A      |
# |    0   N/A  N/A     15176    C+G   ...siveControlPanel\SystemSettings.exe      N/A      |
# |    0   N/A  N/A     19628    C+G   ...CBS_cw5n1h2txyewy\TextInputHost.exe      N/A      |
# |    0   N/A  N/A     20756    C+G   ... Stream\114.0.1.0\GoogleDriveFS.exe      N/A      |
# |    0   N/A  N/A     21448    C+G   ...3.0_x64__cv1g1gvanyjgm\WhatsApp.exe      N/A      |
# |    0   N/A  N/A     24536    C+G   C:\Windows\explorer.exe                     N/A      |
# |    0   N/A  N/A     24960    C+G   ....0_x64__8she8kybcnzg4\app\Slack.exe      N/A      |
# |    0   N/A  N/A     25916    C+G   ...ekyb3d8bbwe\PhoneExperienceHost.exe      N/A      |
# |    0   N/A  N/A     26596    C+G   ...on\140.0.3485.66\msedgewebview2.exe      N/A      |
# +-----------------------------------------------------------------------------------------+

# %%
import torch
import bitsandbytes as bnb

x = torch.randn(3, 3, device="cuda")
w = bnb.nn.Int8Params(x)
print(w.device)  # should print: cuda:0
# Out:
# cuda:0

# %%
print(moondream)
# Out:
# HfMoondream(
#   (model): MoondreamModel(
#     (vision): ModuleDict(
#       (patch_emb): Linear8bitLt(in_features=588, out_features=1152, bias=True)
#       (blocks): ModuleList(
#         (0-26): 27 x ModuleDict(
#           (ln1): LayerNorm((1152,), eps=1e-05, elementwise_affine=True)
#           (attn): ModuleDict(
#             (qkv): Linear8bitLt(in_features=1152, out_features=3456, bias=True)
#             (proj): Linear8bitLt(in_features=1152, out_features=1152, bias=True)
#           )
#           (ln2): LayerNorm((1152,), eps=1e-05, elementwise_affine=True)
#           (mlp): ModuleDict(
#             (fc1): Linear8bitLt(in_features=1152, out_features=4304, bias=True)
#             (fc2): Linear8bitLt(in_features=4304, out_features=1152, bias=True)
#           )
#         )
#       )
#       (post_ln): LayerNorm((1152,), eps=1e-05, elementwise_affine=True)
#       (proj_mlp): ModuleDict(
#         (fc1): Linear8bitLt(in_features=2304, out_features=8192, bias=True)
#         (fc2): Linear8bitLt(in_features=8192, out_features=2048, bias=True)
#       )
#     )
#     (text): ModuleDict(
#       (blocks): ModuleList(
#         (0-1): 2 x ModuleDict(
#           (ln): LayerNorm((2048,), eps=1e-05, elementwise_affine=True)
#           (attn): ModuleDict(
#             (qkv): Linear8bitLt(in_features=2048, out_features=6144, bias=True)
#             (proj): Linear8bitLt(in_features=2048, out_features=2048, bias=True)
#             (tau): ParameterDict(
#                 (alpha): Parameter containing: [torch.cuda.HalfTensor of size 32 (cuda:0)]
#                 (wq): Parameter containing: [torch.cuda.HalfTensor of size 32x6144 (cuda:0)]
#                 (wv): Parameter containing: [torch.cuda.HalfTensor of size 32x6144 (cuda:0)]
#             )
#           )
#           (mlp): ModuleDict(
#             (fc1): Linear8bitLt(in_features=2048, out_features=8192, bias=True)
#             (fc2): Linear8bitLt(in_features=8192, out_features=2048, bias=True)
#           )
#         )
#         (2): ModuleDict(
#           (ln): LayerNorm((2048,), eps=1e-05, elementwise_affine=True)
#           (attn): ModuleDict(
#             (qkv): Linear8bitLt(in_features=2048, out_features=6144, bias=True)
#             (proj): Linear8bitLt(in_features=2048, out_features=2048, bias=True)
#             (tau): ParameterDict(
#                 (alpha): Parameter containing: [torch.meta.HalfTensor of size 32]
#                 (wq): Parameter containing: [torch.meta.HalfTensor of size 32x6144]
#                 (wv): Parameter containing: [torch.meta.HalfTensor of size 32x6144]
#             )
#           )
#           (mlp): ModuleDict(
#             (fc1): Linear8bitLt(in_features=2048, out_features=8192, bias=True)
#             (fc2): Linear8bitLt(in_features=8192, out_features=2048, bias=True)
#           )
#         )
#         (3): ModuleDict(
#           (ln): LayerNorm((2048,), eps=1e-05, elementwise_affine=True)
#           (attn): ModuleDict(
#             (qkv): Linear8bitLt(in_features=2048, out_features=6144, bias=True)
#             (proj): Linear8bitLt(in_features=2048, out_features=2048, bias=True)
#             (tau): ParameterDict(
#                 (alpha): Parameter containing: [torch.meta.BFloat16Tensor of size 32]
#                 (wq): Parameter containing: [torch.meta.BFloat16Tensor of size 32x6144]
#                 (wv): Parameter containing: [torch.meta.BFloat16Tensor of size 32x6144]
#             )
#           )
#           (mlp): ModuleDict(
#             (fc1): Linear8bitLt(in_features=2048, out_features=8192, bias=True)
#             (fc2): Linear8bitLt(in_features=8192, out_features=2048, bias=True)
#           )
#         )
#         (4-23): 20 x ModuleDict(
#           (ln): LayerNorm((2048,), eps=1e-05, elementwise_affine=True)
#           (attn): ModuleDict(
#             (qkv): Linear8bitLt(in_features=2048, out_features=6144, bias=True)
#             (proj): Linear8bitLt(in_features=2048, out_features=2048, bias=True)
#             (tau): ParameterDict(
#                 (alpha): Parameter containing: [torch.meta.BFloat16Tensor of size 32]
#                 (wq): Parameter containing: [torch.meta.BFloat16Tensor of size 32x6144]
#                 (wv): Parameter containing: [torch.meta.BFloat16Tensor of size 32x6144]
#             )
#           )
#           (mlp): ModuleDict(
#             (router): Linear8bitLt(in_features=2048, out_features=64, bias=True)
#             (fc1): ParameterDict(  (weight): Parameter containing: [torch.meta.BFloat16Tensor of size 64x2048x2048])
#             (fc2): ParameterDict(  (weight): Parameter containing: [torch.meta.BFloat16Tensor of size 64x2048x1024])
#           )
#         )
#       )
#       (post_ln): LayerNorm((2048,), eps=1e-05, elementwise_affine=True)
#       (lm_head): Linear8bitLt(in_features=2048, out_features=51200, bias=True)
#     )
#     (region): ModuleDict(
#       (coord_encoder): Linear8bitLt(in_features=256, out_features=2048, bias=True)
#       (coord_decoder): Linear8bitLt(in_features=2048, out_features=1024, bias=True)
#       (size_encoder): Linear8bitLt(in_features=512, out_features=2048, bias=True)
#       (size_decoder): Linear(in_features=2048, out_features=2048, bias=True)
#     )
#   )
# )

# %% [markdown]
# ### Check Model Size

# %%
num_params = sum(p.numel() for p in moondream.parameters())
print("Parameters:", num_params)

dtype = next(moondream.parameters()).dtype
bytes_per_param = {torch.float32: 4, torch.float16: 2, torch.bfloat16: 2}.get(dtype, 4)
size_gb = num_params * bytes_per_param / (1024**3)
print(f"Approx size in memory: {size_gb:.2f} GB")
# Out:
# Parameters: 9268622832
# Approx size in memory: 17.26 GB

# %% [markdown]
# ### Load Images

# %%
bird_img = Image.open("../../tasks/bird.jpg")
apple_img = Image.open("../../tasks/apples.png")
trip_img = Image.open("../../tasks/cable-trip.jpg")
ocr_img = Image.open("../../tasks/ocr.png")

# Display the image
plt.figure(figsize=(14,7))
plt.subplot(221); plt.imshow(bird_img); plt.title("Humming Bird"); plt.axis('off');
plt.subplot(222); plt.imshow(apple_img); plt.title("Apples Green"); plt.axis('off');
plt.subplot(223); plt.imshow(trip_img); plt.title("Person Tripping"); plt.axis('off');
plt.subplot(224); plt.imshow(ocr_img); plt.title("Image with Text"); plt.axis('off');

# %% [markdown]
# ### Short Caption

# %%
# Long caption
torch.cuda.reset_peak_memory_stats()
t1 = time.time()
short = moondream.caption(bird_img, length="short")
t2 = time.time()

peak = torch.cuda.max_memory_allocated() / (1024**3)
print(f"Peak memory: {peak:.2f} GB")
print(f"Time taken : {round(t2-t1,2)} s")
print(f"\nShort: {short['caption']}")

# %% [markdown]
# ### Medium Caption

# %%
# Long caption
torch.cuda.reset_peak_memory_stats()
t1 = time.time()
normal = moondream.caption(bird_img, length="normal")
t2 = time.time()

peak = torch.cuda.max_memory_allocated() / (1024**3)
print(f"Peak memory: {peak:.2f} GB")
print(f"Time taken : {round(t2-t1,2)} s")
print(f"\nNormal: {normal['caption']}")
# Out:
# Peak memory: 18.27 GB
# Time taken : 27.95 s
#
# Normal: A hummingbird is captured in mid-flight near a vibrant orange and white flower. The bird's wings are outstretched, and its beak is pointed downward. The flower features a prominent central spike with smaller spikes extending outward, creating a striking contrast in color and texture. The background is a soft, blurred blend of yellow and green hues, providing a natural and serene setting for the scene.

# %% [markdown]
# ### Long Caption

# %%
# Long caption
torch.cuda.reset_peak_memory_stats()
t1 = time.time()
long = moondream.caption(bird_img, length="long")
t2 = time.time()

peak = torch.cuda.max_memory_allocated() / (1024**3)
print(f"Peak memory: {peak:.2f} GB")
print(f"Time taken : {round(t2-t1,2)} s")
print(f"\nLong: {long['caption']}")
# Out:
# Peak memory: 18.33 GB
# Time taken : 73.54
#
# Long: The image presents a close-up view of a hummingbird in mid-flight, hovering near a vibrant flower. The hummingbird is positioned slightly to the right of the center of the frame, with its wings fully extended and its body angled downward. Its long, slender beak is pointed downward, and its body is covered in gray feathers with hints of green on its wings. The hummingbird's tail is black, and its wings are spread out, indicating its active state.
#
# The flower is a striking feature of the image, located on the left side of the frame. It is tall and slender, with a reddish-orange color at the top transitioning to a pale yellow-orange at the bottom. The flower's structure is intricate, with numerous thin filaments extending outward. At the base of the flower, there is a small green stem. The flower's color gradient adds a dynamic element to the composition.
#
# The background of the image is a soft, blurred yellow-green gradient, which helps to emphasize the hummingbird and the flower. The background is out of focus, creating a sense of depth and drawing attention to the main subjects. The overall composition of the image is balanced, with the hummingbird and the flower as the focal points. The image captures the beauty and interaction between wildlife and their environment, showcasing the delicate movements and behaviors of hummingbirds in their natural habitat.

# %% [markdown]
# ### Point to Objects

# %%
# Find points for specific objects
torch.cuda.reset_peak_memory_stats()
t1 = time.time()
result = moondream.point(apple_img, "Apples in the image")
t2 = time.time()

peak = torch.cuda.max_memory_allocated() / (1024**3)
print(f"Peak memory: {peak:.2f} GB")
print(f"Time taken : {round(t2-t1,2)} s")

width = apple_img.width
height = apple_img.height

annotated_img = apple_img.copy()
draw = ImageDraw.Draw(annotated_img)

rad = 5

# Points are normalized coordinates (0-1)
for i, point in enumerate(result["points"]):
    abs_x = int(point['x'] * width)
    abs_y = int(point['y'] * height)
    print(f"Point {i+1}: x={abs_x}, y={abs_y}")
    draw.ellipse((abs_x - rad, abs_y - rad, abs_x + rad, abs_y + rad), outline="red", fill="red")
    draw.ellipse((abs_x - rad*5, abs_y - rad*5, abs_x + rad*5, abs_y + rad*5), outline="blue")
    
    
plt.figure(figsize=(14,7))
plt.imshow(annotated_img); plt.title("Apples detected");
plt.axis("off")
# Out:
# Peak memory: 18.27 GB
# Time taken : 11.02 s
# Point 1: x=368, y=566
# Point 2: x=573, y=603
# Point 3: x=798, y=450
# Point 4: x=768, y=667
# Point 5: x=924, y=366
# Point 6: x=1044, y=487
# Point 7: x=1188, y=493
# Point 8: x=1503, y=450
# (-0.5, 1596.5, 899.5, -0.5)

# %%
# Detect objects with bounding boxes
torch.cuda.reset_peak_memory_stats()
t1 = time.time()
result = moondream.detect(apple_img, "apple")
t2 = time.time()

annotated_bbox = apple_img.copy()
draw = ImageDraw.Draw(annotated_bbox)

peak = torch.cuda.max_memory_allocated() / (1024**3)
print(f"Peak memory: {peak:.2f} GB")
print(f"Time taken : {round(t2-t1,2)} s")

# Bounding boxes are normalized coordinates (0-1)
for i, obj in enumerate(result["objects"]):
    x_min=int(obj['x_min']*width)
    y_min=int(obj['y_min']*height)
    x_max=int(obj['x_max']*width)
    y_max=int(obj['y_max']*height)
    draw.rectangle([x_min, y_min, x_max, y_max], outline="red", width=3)

# # Control maximum number of objects
# settings = {"max_objects": 10}
# result = moondream.detect(image, "person", settings=settings)

plt.figure(figsize=(14,7))
plt.imshow(annotated_bbox); plt.title("Apples detected");
plt.axis("off")
# Out:
# Peak memory: 18.27 GB
# Time taken : 13.8 s
# (-0.5, 1596.5, 899.5, -0.5)

# %% [markdown]
# ### VQA on Images Without Reasoning

# %%
torch.cuda.reset_peak_memory_stats()
t1 = time.time()
# Without reasoning for simple questions
result = moondream.query(
    image=trip_img, 
    question="What is the color of the cable in the image?",
    reasoning=False
)
t2 = time.time()
peak = torch.cuda.max_memory_allocated() / (1024**3)
print(f"Peak memory: {peak:.2f} GB")
print(f"Time taken : {round(t2-t1,2)} s")

print(result["answer"])
# Out:
# Peak memory: 18.27 GB
# Time taken : 9.22 s
# The color of the cable in the image is yellow.

# %% [markdown]
# ### VQA on Images With Reasoning

# %%
torch.cuda.reset_peak_memory_stats()
t1 = time.time()
# Without reasoning for simple questions
result = moondream.query(
    image=trip_img, 
    question="Why is the person falling?",
    # reasoning=False
)
t2 = time.time()
peak = torch.cuda.max_memory_allocated() / (1024**3)
print(f"Peak memory: {peak:.2f} GB")
print(f"Time taken : {round(t2-t1,2)} s")

print(result["answer"])
# Out:
# Peak memory: 18.27 GB
# Time taken : 15.37 s
# The person is falling because he is tripping over the yellow extension cord on the floor.

# %% [markdown]
# ### Caching Image Encoding

# %%
# Encode image once
t1 = time.time()
encoded = moondream.encode_image(trip_img)
t2 = time.time()
print(f"Time taken : {round(t2-t1,2)} s")
# Out:
# Time taken : 5.68 s

# %%
question = "What is the color of the cable in the image?"
t1 = time.time()
result = moondream.query(image=encoded, question=question, reasoning=True)
t2 = time.time()
print(f"Time taken : {round(t2-t1,2)} s")
print(result["answer"])
# Out:
# Time taken : 3.67 s
# yellow

# %%
question = "Why is the person falling?"
t1 = time.time()
result = moondream.query(image=encoded, question=question, reasoning=True)
t2 = time.time()
print(f"Time taken : {round(t2-t1,2)} s")
print(result["answer"])
# Out:
# Time taken : 22.42 s
# The person is falling because he is tripping over a yellow cord on the floor.

# %% [markdown]
# ### Testing OCR Capability

# %%
torch.cuda.reset_peak_memory_stats()
t1 = time.time()
# Without reasoning for simple questions
result = moondream.caption(
    image=ocr_img,
    length='long'
)
t2 = time.time()
peak = torch.cuda.max_memory_allocated() / (1024**3)
print(f"Peak memory: {peak:.2f} GB")
print(f"Time taken : {round(t2-t1,2)} s")

print(result["caption"])
# Out:
# Peak memory: 18.40 GB
# Time taken : 103.15 s
# The image presents a slide from a presentation titled "Gemma 2: Improving Open Language Models at a Practical Size." The slide is structured with a title at the top, followed by the Gemma Team and Google DeepMind logo. The text is neatly organized into paragraphs, providing a detailed description of the project.
#
# The first paragraph introduces Gemma 2, a new addition to the Gemma family of lightweight, state-of-the-art open models. It spans a range of scales from 2 billion to 27 billion parameters. The slide highlights several technical modifications applied to the Transformer architecture, including interleaving local-global attentions and group-query attention. The authors also mention training the 2B and 9B models with knowledge distillation instead of next token prediction. The resulting models deliver the best performance for their size while offering competitive alternatives to models 2-3x bigger. The slide concludes by announcing the release of all models to the community.
#
# The text is presented in a clear, readable font against a light beige background. The paragraphs are aligned to the left, and the text is left-aligned. The Gemma Team and Google DeepMind logo are positioned at the top left corner of the slide, emphasizing the collaboration between the two entities. The slide's design is simple and professional, focusing on conveying information about the project's objectives and achievements.
#
# The slide's content is well-structured, with each paragraph providing specific details about the Gemma 2 model, its improvements, and its impact on the field of natural language processing. The use of technical terms like "lightweight," "state-of-the-art," and "knowledge distillation" adds depth to the description, showcasing the innovative approach taken by the team. The slide effectively communicates the significance of Gemma 2 and its contributions to improving open language models.

# %% [markdown]
# ### OCR on Chart Data

# %%
table_img = Image.open('../../tasks/table.png')
plt.figure(figsize=(16,8))
plt.imshow(table_img); plt.title("Chart on Image");
plt.axis("off")
# Out:
# (-0.5, 1919.5, 1079.5, -0.5)

# %%
torch.cuda.reset_peak_memory_stats()
t1 = time.time()
# Without reasoning for simple questions
result = moondream.query(
    image=table_img, 
    question="Can you output the table in the image in markdown format?",
    reasoning=False
)
t2 = time.time()
peak = torch.cuda.max_memory_allocated() / (1024**3)
print(f"Peak memory: {peak:.2f} GB")
print(f"Time taken : {round(t2-t1,2)} s")

print(result["answer"])
# Out:
# Peak memory: 18.40 GB
# Time taken : 62.12 s
# | SL NO | Particulars | Qty | Make |
# | ------ | ---------- | ---- | --- |
# | A | INCOMER | 1 | L&K |
# | 1 | 32A MCB 4P, C Curve | 1 | L&K |
# | 2 | Voltage Monitoring Relay | 1 | L&K |
# | 3 | 40A Contactor 4P, MCX-04 | 1 | L&K |
# | 4 | Red LVGP Indicator | 1 | ESBEE |
# | 5 | Green LVGP Indicator | 1 | ESBEE |
# | 6 | Blue LVGP Indicator | 1 | ESBEE |
# | 7 | 6A Fuse Terminal | 3 | FTC |
# | 8 | Emergency Push Button Stay Put, Rotate to Reset with NC Element | 1 | C&S |
