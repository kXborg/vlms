# %%
# !uv pip install hf_transfer tqdm ipywidgets

# %%
# !pip install matplotlib

# %%
# !git clone https://github.com/kXborg/vlms.git

# %%
# %cd vlms

# %%
import time

# %%
from PIL import Image
import matplotlib.pyplot as plt
from vllm import LLM, SamplingParams
from vllm.model_executor.models.deepseek_ocr import NGramPerReqLogitsProcessor

# %%
# Create model instance
llm = LLM(
    model="deepseek-ai/DeepSeek-OCR",
    enable_prefix_caching=False,
    mm_processor_cache_gb=0,
    logits_processors=[NGramPerReqLogitsProcessor]
)
# Out:
# INFO 11-14 14:12:47 [utils.py:253] non-default args: {'enable_prefix_caching': False, 'disable_log_stats': True, 'mm_processor_cache_gb': 0, 'logits_processors': [<class 'vllm.model_executor.models.deepseek_ocr.NGramPerReqLogitsProcessor'>], 'model': 'deepseek-ai/DeepSeek-OCR'}
# INFO 11-14 14:13:58 [model.py:631] Resolved architecture: DeepseekOCRForCausalLM
# INFO 11-14 14:13:58 [model.py:1745] Using max model len 8192
# INFO 11-14 14:14:11 [scheduler.py:260] Chunked prefill is enabled with max_num_batched_tokens=8192.
# ...

# %%
# !ls
# Out:
# DeepSeek-OCR-vLLM-13-11-25.ipynb  github-png-readme.md	requirements.txt
# DeepSeek-OCR-vLLM.ipynb		  output		result.mmd
# Deepseek-OCR-Q4.ipynb		  output2		result_with_boxes.jpg
# Deepseek-OCR.ipynb		  output3
# github-png-readme		  output4

# %% [markdown]
# ### Input Document - Images

# %%
# Prepare batched input with your image file
image_1 = Image.open("../../../dataset/pdf-images2/1.jpg").convert("RGB")
image_2 = Image.open("../../../dataset/pdf-images2/2.jpg").convert("RGB")
image_3 = Image.open("../../../dataset/pdf-images2/3.jpg").convert("RGB")

# %%
plt.figure(figsize=(14,7))
plt.subplot(131); plt.imshow(image_1); plt.title('test'); plt.axis('off');
plt.subplot(132); plt.imshow(image_2); plt.title('test'); plt.axis('off');
plt.subplot(133); plt.imshow(image_3); plt.title('test'); plt.axis('off');

# %%
def run_inference(promt, model):
    model_input = [
        {
            "prompt": prompt,
            "multi_modal_data": {"image": image_1}
        },
        {
            "prompt": prompt,
            "multi_modal_data": {"image": image_2}
        },
        {
            "prompt": prompt,
            "multi_modal_data": {"image": image_3}
        },]

    sampling_param = SamplingParams(
            temperature=0.0,
            max_tokens=8192,
            # ngram logit processor args
            extra_args=dict(
                ngram_size=30,
                window_size=90,
                whitelist_token_ids={128821, 128822},
            ),
            skip_special_tokens=False,
        )

    t1 = time.time()
    # Generate output
    model_outputs = llm.generate(model_input, sampling_param)
    t2 = time.time()
    
    print(f"Time taken to process the images: {round(t2-t1, 2)}s")
    
    # Print output
    for output in model_outputs:
        print(output.outputs[0].text)

    return model_outputs

# %% [markdown]
# ### Test 1: Free OCR

# %%
prompt = "\nFree OCR."
free_ocr = run_inference(prompt, llm)
# Out:
# ...
# Processed prompts:   0%|          | 0/3 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# Time taken to process the images: 4.2s
# HDW070_008LZ02
#
# 7英寸，1024×600像素点阵，16.7M色，IPS屏
# 电容触摸屏，HDMI多媒体显示屏
#
# 7 Inch, 1024xRGBx600, 16.7M Colors, IPS screen
# CTP, HDMI multimedia display
#
# 修订记录 Record of Revision
#
# | 版本/Ver | 日期/Revise Date | 描述/Content | 编辑人/Editor |
# |---------|-----------------|--------------|---------------|
# | 00      | 2022-04-14      | 首次发布 First Edition | 郑运佳 |
# | 01      | 2022-07-08      | 更新实物图 Update the physical drawing | 郑运佳 |
#
# 迪文科技 DWIN Technologies 400 018 9008 www.dwin.com.cn
# ### 显示性能参数 Display
#
# | 参数 Item | 数据 Parameter | 说明 Description |
# |----------|---------------|----------------|
# | 颜色 Color | 16.7M(16777216)colors | 24 bit color 8R8G8B |
# | 液晶类型 Panel Type | IPS | IPS 工艺 TFT 显示屏，宽视角 IPS TFT LCM, wide viewing angle |
# | 可视角度 Viewing Angle | 85/85/85/85 (L/R/U/D) | 最佳视角：上下左右对称 Best View: symmetrical |
# ...

# %% [markdown]
# ### Test 2: OCR + Convert To Markdown

# %%
prompt = "\n<|grounding|>Convert the document to markdown."
ocr_md = run_inference(prompt, llm)
# Out:
# ...
# Processed prompts:   0%|          | 0/3 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# Time taken to process the images: 5.34s
# <|ref|>title<|/ref|><|det|>[[346, 90, 672, 117]]<|/det|>
# # HDW070_008LZ02
#
# <|ref|>text<|/ref|><|det|>[[237, 146, 784, 208]]<|/det|>
# 7英寸， \(1024\times 600\) 像素点阵，16.7M色，IPS 屏电容触摸屏，HDMI多媒体显示屏
#
# <|ref|>text<|/ref|><|det|>[[235, 221, 785, 282]]<|/det|>
# 7 Inch, 1024xRGBx600, 16.7M Colors, IPS screenCTP, HDMI multimedia display
#
# <|ref|>image<|/ref|><|det|>[[247, 300, 773, 800]]<|/det|>
#
# <|ref|>table<|/ref|><|det|>[[115, 860, 902, 919]]<|/det|>
# <|ref|>table_caption<|/ref|><|det|>[[113, 845, 355, 860]]<|/det|>
# 修订记录 Record of Revision
#
# <table><tr><td>版本/Ver</td><td>日期/Revise Date</td><td>描述/Content</td><td>编辑人/Editor</td></tr><tr><td>00</td><td>2022-04-14</td><td>首次发布 First Edition</td><td>郑运佳</td></tr><tr><td>01</td><td>2022-07-08</td><td>更新实物图 Update the physical drawing</td><td>郑运佳</td></tr></table>
# ...

# %%
## Display Markdown Output

# %%
from IPython.display import display, Markdown

# %%
md = []
for output in ocr_md:
    md.append(output.outputs[0].text)
    
display(Markdown(
    """
<|ref|>title<|/ref|><|det|>[[346, 90, 672, 117]]<|/det|>
# HDW070_008LZ02  

<|ref|>text<|/ref|><|det|>[[237, 146, 784, 208]]<|/det|>
7英寸， \(1024\times 600\) 像素点阵，16.7M色，IPS 屏电容触摸屏，HDMI多媒体显示屏  

<|ref|>text<|/ref|><|det|>[[235, 221, 785, 282]]<|/det|>
7 Inch, 1024xRGBx600, 16.7M Colors, IPS screenCTP, HDMI multimedia display  

<|ref|>image<|/ref|><|det|>[[247, 300, 773, 800]]<|/det|>  

<|ref|>table<|/ref|><|det|>[[115, 860, 902, 919]]<|/det|>
<|ref|>table_caption<|/ref|><|det|>[[113, 845, 355, 860]]<|/det|>
修订记录 Record of Revision   

<table><tr><td>版本/Ver</td><td>日期/Revise Date</td><td>描述/Content</td><td>编辑人/Editor</td></tr><tr><td>00</td><td>2022-04-14</td><td>首次发布 First Edition</td><td>郑运佳</td></tr><tr><td>01</td><td>2022-07-08</td><td>更新实物图 Update the physical drawing</td><td>郑运佳</td></tr></table>
<|ref|>table<|/ref|><|det|>[[115, 84, 903, 377]]<|/det|>
<|ref|>table_caption<|/ref|><|det|>[[75, 68, 285, 83]]<|/det|>
显示性能参数 Display   

<table><tr><td>参数 Item</td><td>数据 Parameter</td><td>说明 Description</td></tr><tr><td>颜色 Color</td><td>16.7M(16777216)colors</td><td>24 bit color 8R8G8B</td></tr><tr><td>液晶类型 Panel Type</td><td>IPS</td><td>IPS 工艺 TFT 显示屏，宽视角<br>IPS TFT LCM,wide viewing angle</td></tr><tr><td>可视角度 Viewing Angle</td><td>85/85/85/85 (L/R/U/D)</td><td>最佳视角：上下左右对称<br>Best View: symmetrical</td></tr><tr><td>显示尺寸 Active Area (A.A.)</td><td>154.08(W) ×85.92(H)</td><td>1024x600</td></tr><tr><td>视域尺寸 View Area (V.A.)</td><td>154.08(W) ×85.92(H)</td><td>1024x600</td></tr><tr><td>分辨率 Resolution</td><td>1024x600</td><td>-</td></tr><tr><td>背光模式 Backlight</td><td>LED</td><td>不低于 20000H（以最高亮度连续工作、亮度减半时间）<br>≥20000H(Continuous working、with maximum brightness, time of the brightness decays to 50%)</td></tr><tr><td>亮度 Brightness</td><td>600nit</td><td>-</td></tr><tr><td colspan="3">注：超过 30 分钟长时间显示高对比度静止画面可能导致显示残影，请增加屏保避免该问题。<br>Note: Displaying of high-contrast still images for more than 30 minutes may result in residual images. Please add animation to avoid this problem.</td></tr></table>  

<|ref|>table<|/ref|><|det|>[[115, 395, 902, 560]]<|/det|>
<|ref|>table_caption<|/ref|><|det|>[[75, 380, 353, 395]]<|/det|>
电能性参数 Voltage & Current   

<table><tr><td>参数 Item</td><td colspan="2">说明 Descriptions</td></tr><tr><td>工作电压 Power Voltage</td><td colspan="2">6~36V，典型值 12V</td></tr><tr><td rowspan="3">电流参数 Current parameters</td><td>720mA</td><td>VCC=6V（最低启动电压）<br>VCC=6V（Minimum starting voltage）</td></tr><tr><td>330mA</td><td>VCC=12V（标准供电电压）<br>VCC=12V（Standard supply voltage）</td></tr><tr><td>140mA</td><td>VCC=36V（最高供电电压）<br>VCC=36V（Maximum supply voltage）</td></tr><tr><td colspan="3">推荐工作电源：12V 1A 的直流稳压电源<br>Recommended power supply: 12V 1A DC</td></tr></table>  

<|ref|>table<|/ref|><|det|>[[115, 577, 902, 799]]<|/det|>
<|ref|>table_caption<|/ref|><|det|>[[75, 562, 415, 576]]<|/det|>
工作环境和可靠性参数 Reliability Test   

<table><tr><td>参数 Item</td><td>测试条件 Conditions</td><td>最小值 Min</td><td>典型值 Typ</td><td>最大值 Max</td><td>单位 Unit</td></tr><tr><td>工作温度 Working Temperature</td><td>12V 电压下，湿度 60% 60%RH at 12V voltage</td><td>-20</td><td>25</td><td>70</td><td>℃</td></tr><tr><td>储存温度 Storage Temperature</td><td>-</td><td>-30</td><td>25</td><td>80</td><td>℃</td></tr><tr><td>工作湿度 Working Humidity</td><td>25℃</td><td>10%</td><td>60%</td><td>90%</td><td>RH</td></tr><tr><td rowspan="2">静电放电测试 Electrostatic discharge test</td><td>接触放电 Contact discharge</td><td>-</td><td>±6KV</td><td>-</td><td>-</td></tr><tr><td>空气放电 Air discharge</td><td>-</td><td>±8KV</td><td>-</td><td>-</td></tr><tr><td>电快速瞬变脉冲群 EFT</td><td></td><td>-</td><td>±2KV</td><td>-</td><td>-</td></tr></table>  

<|ref|>table<|/ref|><|det|>[[115, 816, 902, 932]]<|/det|>
<|ref|>table_caption<|/ref|><|det|>[[75, 800, 295, 815]]<|/det|>
接口性能参数 Interface   

<table><tr><td>参数 Item</td><td>测试条件 Conditions</td><td>最小值 Min</td><td>典型值 Typ</td><td>最大值 Max</td><td>单位 Unit</td></tr><tr><td>用户接口方式 Socket</td><td>电源接口，HDMI接口 power interface, HDMI interface</td><td></td><td></td><td></td><td></td></tr><tr><td>USB接口</td><td>有（外接USB电容触摸屏） Yes (Connect USB capacitive touch screen)</td><td></td><td></td><td></td><td></td></tr><tr><td>SD卡接口 SD Slot</td><td>无 None</td><td></td><td></td><td></td><td></td></tr></table>
<|ref|>sub_title<|/ref|><|det|>[[70, 68, 273, 83]]<|/det|>
## 外设支持 Peripheral  

<|ref|>table<|/ref|><|det|>[[120, 84, 904, 115]]<|/det|>

<table><tr><td>支持外设</td><td>支持电容式触摸屏</td></tr><tr><td>Peripheral</td><td>Capacitive touch panel</td></tr></table>  

<|ref|>sub_title<|/ref|><|det|>[[70, 114, 500, 129]]<|/det|>
## 包装和物理尺寸 Packing Capacity & Dimension  

<|ref|>table<|/ref|><|det|>[[120, 130, 904, 200]]<|/det|>

<table><tr><td colspan="2">尺寸 Dimension</td></tr><tr><td>外形尺寸<br>Dimension</td><td>184.08(W)×115.92(H)×17.75(T)mm</td></tr><tr><td>净重量<br>Net Weight</td><td>200g</td></tr></table>  

<|ref|>text<|/ref|><|det|>[[70, 216, 432, 232]]<|/det|>
声明：产品设计改善或变更，不单独另行通知。  

<|ref|>text<|/ref|><|det|>[[70, 236, 800, 252]]<|/det|>
Disclaimer: The product design is subject to alternation and improvement without prior notice.
"""
))
# Out:
# <>:6: SyntaxWarning: invalid escape sequence '\('
# <>:6: SyntaxWarning: invalid escape sequence '\('
# /tmp/ipykernel_1433/2571067809.py:6: SyntaxWarning: invalid escape sequence '\('
#   """
# <|ref|>title<|/ref|><|det|>[[346, 90, 672, 117]]<|/det|>
# # HDW070_008LZ02
#
# <|ref|>text<|/ref|><|det|>[[237, 146, 784, 208]]<|/det|>
# 7英寸， \(1024	imes 600\) 像素点阵，16.7M色，IPS 屏电容触摸屏，HDMI多媒体显示屏
#
# <|ref|>text<|/ref|><|det|>[[235, 221, 785, 282]]<|/det|>
# 7 Inch, 1024xRGBx600, 16.7M Colors, IPS screenCTP, HDMI multimedia display
#
# <|ref|>image<|/ref|><|det|>[[247, 300, 773, 800]]<|/det|>
#
# <|ref|>table<|/ref|><|det|>[[115, 860, 902, 919]]<|/det|>
# <|ref|>table_caption<|/ref|><|det|>[[113, 845, 355, 860]]<|/det|>
# 修订记录 Record of Revision
#
# ...
