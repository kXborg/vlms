# %%
import uvicorn
from llmApp import app

uvicorn.run(app, host="0.0.0.0", port=9000)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[2], line 4
#       1 import uvicorn
#       2 from llmApp import app
# ----> 4 uvicorn.run(app, host="0.0.0.0", port=9000)
#
# ...
